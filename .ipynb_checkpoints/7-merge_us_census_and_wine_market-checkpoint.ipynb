# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load and merge datasets

# %%
wine_market_data = pd.read_csv("wine_market_statistics_clean.csv")
wine_market_data.shape
# Out:
# (24, 8)

# %%
census_data = pd.read_csv("us_census_merged_clean.csv")
census_data.shape
# Out:
# (24, 15)

# %%
merged_data = pd.merge(wine_market_data, census_data, on='Year', how="outer")
merged_data.shape
# Out:
# (24, 22)

# %%
merged_data.head(10)
# Out:
#    Year  Premium Wineries Gross Margins (%)  US Wine Market Share (%)  \
# 0  1999                                 NaN                       NaN
# 1  2000                                 NaN                       NaN
# 2  2001                                 NaN                       NaN
# 3  2002                                51.5                       NaN
# 4  2003                                50.2                       NaN
# 5  2004                                51.5                       NaN
# 6  2005                                52.8                       NaN
# 7  2006                                54.5                       NaN
# 8  2007                                57.1                       NaN
# 9  2008                                55.3                       NaN
#
#    US Wine Consumption (Mgal)  US Wine Production (Mgal)  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                       687.0                        NaN
# 7                       707.0                     623.26
# 8                       746.0                     637.67
# 9                       747.0                     619.68
#
#    California Wine Production (Mgal)  US Wine Sales Volume (Mgal)  \
# 0                                NaN                   543.032096
# 1                                NaN                   567.996356
# 2                                NaN                   573.940227
# 3                                NaN                   594.387145
# 4                                NaN                   633.854451
# 5                                NaN                   662.860544
# 6                                NaN                   687.349294
# 7                             557.13                   706.845193
# 8                             565.95                   746.074744
# 9                             545.86                   747.263519
#
#    Californian Wine Market Value ($Bn)  Num w/ small children  Median Income  \
# 0                                  NaN             33485000.0          67650
# 1                                  NaN             33255875.0          67470
# 2                                  NaN             33026750.0          66360
# 3                                  NaN             32797625.0          65820
# 4                                  NaN             32568500.0          65860
# 5                                  NaN             32339375.0          65760
# 6                                  NaN             32110250.0          66780
# 7                                 25.7             31881125.0          67520
# 8                                 25.7             31652000.0          68610
# 9                                 26.7             30539000.0          66280
#
#    ...    Num Kids  Num Seniors   Num Teens  Num Young Adults  \
# 0  ...  64529000.0   25607400.0  19934400.0        19653800.0
# 1  ...  63567750.0   27764050.0  19996050.0        19711350.0
# 2  ...  62606500.0   29920700.0  20057700.0        19768900.0
# 3  ...  61645250.0   32077350.0  20119350.0        19826450.0
# 4  ...  60684000.0   34234000.0  20181000.0        19884000.0
# 5  ...  60752000.0   34659000.0  20313000.0        20339000.0
# 6  ...  40467000.0   35210000.0  20662000.0        20408000.0
# 7  ...  60640000.0   35505000.0  20916000.0        20393000.0
# 8  ...  40274000.0   50006000.0  21170000.0        20532000.0
# 9  ...  40056000.0   51720000.0  21314000.0        20529000.0
#
#    Total Population   High School  Some College  Bachelor's degree  \
# 0      2.810852e+08  6.658568e+07  5.622953e+07       3.062268e+07
# 1      2.822977e+08  6.692895e+07  5.670542e+07       3.169695e+07
# 2      2.835101e+08  6.727221e+07  5.718132e+07       3.277121e+07
# 3      2.847226e+08  6.761547e+07  5.765721e+07       3.384547e+07
# 4      2.859350e+08  6.795874e+07  5.813311e+07       3.491974e+07
# 5      2.882820e+08  6.830200e+07  5.860900e+07       3.599400e+07
# 6      2.709070e+08  6.944600e+07  5.927600e+07       3.652000e+07
# 7      2.938360e+08  6.954800e+07  6.061500e+07       3.733400e+07
# 8      2.762980e+08  7.026600e+07  6.068100e+07       3.894000e+07
# 9      2.782050e+08  6.970200e+07  6.287500e+07       4.009400e+07
#
#    Advanced degree  Basic education
# 0     1.431447e+07       51486500.0
# 1     1.507258e+07       50896812.5
# 2     1.583068e+07       50307125.0
# 3     1.658879e+07       49717437.5
# 4     1.734689e+07       49127750.0
# 5     1.810500e+07       48538062.5
# 6     1.822500e+07       47948375.0
# 7     1.873400e+07       47358687.5
# 8     1.936400e+07       46769000.0
# 9     2.039600e+07       45080000.0
#
# [10 rows x 22 columns]

# %%
merged_data.to_csv("forecast_data.csv", index=False)

# %% [markdown]
# ## Correlations

# %%
def calculate_correlation(dataframe):
    # Calculate correlation matrix for the given DataFrame
    correlation_matrix = dataframe.corr()
    return correlation_matrix

# %%
def visualize_correlation(correlation_matrix, figsize=(8,5)):
    # Visualize the correlation matrix using a heatmap
    plt.figure(figsize=figsize)
    sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=.5)
    plt.title('Correlation Between Variables')
    #plt.xlabel('Time Series')
    #plt.ylabel('Time Series')
    plt.show()

# %%
visualize_correlation(calculate_correlation(merged_data), figsize=(14,12))

# %%
predictors = ["US Wine Production (Mgal)", "Median Income", "Mean Income", "Num Seniors", "Num w/ small children"]
targets = ["Premium Wineries Gross Margins (%)", "US Wine Consumption (Mgal)", "US Wine Sales Volume (Mgal)", "Californian Wine Market Value ($Bn)"]

# %%
data = merged_data[["Year"] + predictors + targets].copy()

# %%
visualize_correlation(calculate_correlation(data))
